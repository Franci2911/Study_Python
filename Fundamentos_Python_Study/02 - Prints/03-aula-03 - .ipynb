# %% [markdown]
# # **`Exercicios 01 e 02 do curso Gustavo Guanabara`**
# > Imprimir Ola, Mundo
# > Solicitar o nome do usuario, e mostrar uma msg do boa vinda ao sistema.

# %%
print('Ola, Mundo')
# Out:
# Ola, Mundo

# %%
nome = input('Qual o nome do usuario: ')
print(f'Seja muito bem vindo, {nome}')
# Out:
# Qual o nome do usuario: Thiago
# Seja muito bem vindo, Thiago
