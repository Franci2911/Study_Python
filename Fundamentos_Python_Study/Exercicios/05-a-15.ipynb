# %% [markdown]
# Exercicios do 05 ao 15
#
#
# > Faça um programa que leia um numero inteiro e mostre o antecessor e o sucessor
#
# > Crie um algorirmo que leia um numero e mostre o dobro, triplo e a Raiz quadrada
#
#
# > Desenvolva um programa que calcula 2 notas de um aluno e mostra a media
#
#
# > EScreve um programa que escreva um valor em metros e mostre em centimetros
#
#
# > Faça um programa que leia um numero qualquer e mostre um tabuada
#
#
# > Crie um programa que leia quanto dinheiro uma pessoa tem na carteira e mostre quantos dolares ela pode comprar - considerar: 1dolar = 3,27
#
#
#
# > Faça um programa que leia a altura e largura de um parede e quantidade de tinta necessario sabendo cada litro de tinra pinta uma area de 2metros.
#
#
#
# > Faça o algoritmo que mostre o preço de um programa com 5% de desconto
#
#
#
# > Faça um algoritmo que leia o salario de um funcionario e mostre seu novo salario com 15% de aumento
#
#
#
# > Escreva um programa que converta uma temperatura digitda em *C e converta para *F
#
#
#
#
# > Exercício Python 015: Escreva um programa que pergunte a quantidade de Km percorridos por um carro alugado e a quantidade de dias pelos quais ele foi alugado. Calcule o preço a pagar, sabendo que o carro custa R$60 por dia e R$0,15 por Km rodado.

# %%
v1 = int(input('Digite um numero: '))
nAtual = v1
nAnterior = v1 - 1
nSucessor = v1 + 1

print(f'O resultado é atual:{nAtual}, anterior:{nAnterior}, Sucessor:{nSucessor}')
# Out:
# Digite um numero: 5
# O resultado é atual:5, anterior:4, Sucessor:6

# %%
v1 = int(input('Digite um numero: '))
print(f'O dobro do {v1} é: {(v1*2)}')
print(f'O triplo do {v1} é: {(v1*3)}')
print(f'A raiz quabrada {v1} é: {(v1**(1/2))}')
print(f'A raiz cubica {v1} é: {(v1**(1/3))}')
# Out:
# Digite um numero: 81
# O dobro do 81 é: 162
# O triplo do 81 é: 243
# A raiz quabrada 81 é: 9.0
# A raiz cubica 81 é: 4.3267487109222245

# %%
Aluno = input('Digite o seu nome: ')
n1 = float(input(f'Qual foi a primeira nota do {Aluno} '))
n2 = float(input(f'Qual foi a segunda nota do {Aluno} '))

media = (n1+n2)/2

print(f'A media final do {Aluno} é de: {media}')
# Out:
# Digite o seu nome: Fran
# Qual foi a primeira nota do Fran 4
# Qual foi a segunda nota do Fran 5
# A media final do Fran é de: 4.5

# %%
v1 = int(input('Quantos metros tem o tampo: '))
convert = (v1 * 100)

print(f'O tamanho do tampo em centimentos é de: {convert}')
# Out:
# Quantos metros tem o tampo: 11
# O tamanho do tampo em centimentos é de: 1100

# %%
v1 = int(input('Digite um numero para eu te mostra a tabuada completa: '))
qtde = 0
for i in range(0, 10):
  qtde += 1
  print(f'{v1} x {qtde} = {v1*qtde}')
print(f'Essa é a tabuada completa do: {v1}')
# Out:
# Digite um numero para eu te mostra a tabuada completa: 8
# 8 x 1 = 8
# 8 x 2 = 16
# 8 x 3 = 24
# 8 x 4 = 32
# 8 x 5 = 40
# 8 x 6 = 48
# 8 x 7 = 56
# 8 x 8 = 64
# 8 x 9 = 72
# 8 x 10 = 80
# Essa é a tabuada completa do: 8

# %%
reais = float(input('Quanto dinheiro você tem: '))
dolar = (reais / 5.11)

print(f'Com R${reais} você pode comprar: U${dolar} ')
# Out:
# Quanto dinheiro você tem: 60
# Com R$60.0 você pode comprar: U$11.741682974559685

# %%
mAltura = float(input('Digite a altura do muro: '))
mLargura = float(input('Digite a largura do muro: '))

tamanhoMuro = (mAltura * mLargura)
print(tamanhoMuro)

litrosTinta = 2
print(f'Eu vou precisar de {tamanhoMuro/litrosTinta} lata de pintar o muro')
# Out:
# Digite a altura do muro: 5
# Digite a largura do muro: 5
# 25.0
# Eu vou precisar de 12.5 lata de pintar o muro

# %%
valor = float(input('Digite o preço do produto: '))
desconto = 13

promocao = valor - (valor * (desconto/100))
print(f'O valor do produto com desconto é de: {promocao} ')
# Out:
# Digite o preço do produto: 97.75
# O valor do produto com desconto é de: 85.0425

# %%
salario = float(input('Digite o seu salario: '))
ajusteSalarial = 15

salarioAjustado = salario + (salario*ajusteSalarial/100)
print(f'Seu novo salario é de: R${salarioAjustado}')
# Out:
# Digite o seu salario: 100
# Seu novo salario é de: R$115.0

# %%
varCelsius = float(input('Informe o grau celsius: '))
varFahrenheit = ( varCelsius * 9 / 5  ) + 32

print(f'A temperatura de {varCelsius} graus*C Celsius, corresponde a {varFahrenheit} graus*F varFahrenheit ' )
# Out:
# Informe o grau celsius: 45
# A temperatura de 45.0 graus*C Celsius, corresponde a 113.0 graus*F varFahrenheit

# %% [markdown]
# ![ConversãoTemperatura.PNG](data:image/png;base64,...)

# %%
kmRodado = float(input('Digite a quantidade de KM rodado: '))
diasLocado = float(input('Digite a quantidade de dias que ficou com o carro: '))

custoKmRodado = 0.15
custoDiasLocado = 60

totalPagarKm = kmRodado * custoKmRodado
totalPagarDiaria = diasLocado * custoDiasLocado

ttp = totalPagarDiaria + totalPagarKm

print(f'O custo total a pagar pelo aluguel do carro é: R${ttp} sendo: R${totalPagarKm} referente ao Km rodado e R${totalPagarDiaria} de diarias ')
# Out:
# Digite a quantidade de KM rodado: 720
# Digite a quantidade de dias que ficou com o carro: 8
# O custo total a pagar pelo aluguel do carro é: R$588.0 sendo: R$108.0 referente ao Km rodado e R$480.0 de diarias
